# %% [markdown]
# # **EGCO 425: Chapter 1 (Introduction)**

# %% [markdown]
# ## Google Colab

# %%
## If using Colab

from google.colab import drive
drive.mount('/content/drive')
#drive.mount('/content/drive', force_remount=True)

import os
os.chdir('/content/drive/MyDrive/Data Mining')          ## replace Workspace/425 with your folder
# %cd /content/drive/MyDrive/Data Mining
# Out:
# Mounted at /content/drive
# /content

# %%
import pandas as pd                                       ## to work with data frame

# %% [markdown]
# ## Read data from CSV

# %% [markdown]
# **[Manual: pandas.read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)**

# %%
### Read data from csv file into DataFrame

DentitionDF = pd.read_csv('./ch1/jupyter/data/dentition.csv')
DentitionDF.head()
# Out:
#          name  top_incisors  bottom_incisors  top_canines  bottom_canines  \
# 0      beaver             1                1            0               0
# 1   groundhog             1                1            0               0
# 2    chipmunk             1                1            0               0
# 3   porcupine             1                1            0               0
# 4  guinea pig             1                1            0               0
#
#    top_premolars  bottom_premolars  top_molars  bottom_molars
# 0              2                 1           3              3
# 1              2                 1           3              3
# 2              2                 1           3              3
# 3              1                 1           3              3
# 4              1                 1           3              3

# %% [markdown]
# ## Read data from Excel

# %% [markdown]
# **[Manual: pandas.read_excel](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)**

# %%
### Read data from excel file into DataFrame

IrisDF = pd.read_excel('./ch1/jupyter/data/IrisFromWeka.xlsx')    ### row 0 = header by default
IrisDF.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ## Load Scikit-learn dataset

# %% [markdown]
# scikit learn has Iris Dataset, Diabetes Dataset, Digits Dataset, Linnerud Dataset, Wine Dataset, Breast Cancer Wisconsin (Diagnostic) Dataset

# %%
from sklearn import datasets

# Load Iris dataset (as bunch object)
IrisBunch = datasets.load_iris(as_frame=True)
IrisDF2   = IrisBunch.frame
IrisDF2
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
print("Attributes \n",  IrisBunch.data)
print("Target \n",      IrisBunch.target)
print("Target name \n", IrisBunch.target_names)
# Out:
# Attributes
#       sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %% [markdown]
# ## DataFrame overview
#
# - First & last records --> **head()**, **tail()**
# - Number of rows & columns --> **shape**
# - Type of each column --> **info()**

# %%
#IrisDF.tail()
IrisDF.shape
#IrisDF.info()
# Out:
# (150, 5)
